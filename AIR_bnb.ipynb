# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
Airbnb_df=pd.read_csv("Airbnb_data.csv")

# %%
Airbnb_df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
Airbnb_df.shape
# Out:
# (48895, 16)

# %%
Airbnb_df.info
# Out:
# <bound method DataFrame.info of              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
Airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
Airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
Airbnb_df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
Airbnb_df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             19-10-2018
# ...

# %%
Airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
rename_col={"id":"listing_id",'name':'listing_name','number_of_reviews':'total_reviews','calculated_host_listings_count':'host_listings_count'}

# %%
Airbnb_df=Airbnb_df.rename(columns=rename_col)
Airbnb_df.head(2)
# Out:
#    listing_id                        listing_name  host_id host_name  \
# 0        2539  Clean & quiet apt home by the park     2787      John
# 1        2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  total_reviews last_review  reviews_per_month  \
# 0    149               1              9  19-10-2018               0.21
# 1    225               1             45  21-05-2019               0.38
#
#    host_listings_count  availability_365
# 0                    6               365
# 1                    2               355

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           48895 non-null  int64
#  1   listing_name         48879 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48874 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   latitude             48895 non-null  float64
#  7   longitude            48895 non-null  float64
#  8   room_type            48895 non-null  object
#  9   price                48895 non-null  int64
#  10  minimum_nights       48895 non-null  int64
#  11  total_reviews        48895 non-null  int64
#  12  last_review          38843 non-null  object
#  13  reviews_per_month    38843 non-null  float64
#  14  host_listings_count  48895 non-null  int64
# ...

# %%
Airbnb_df['reviews_per_month'] =  Airbnb_df['reviews_per_month'].replace(to_replace=np.nan,value=0).astype('int64')

# %%
Airbnb_df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
Airbnb_df.isnull().sum()
# Out:
# listing_id                 0
# listing_name              16
# host_id                    0
# host_name                 21
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# total_reviews              0
# last_review            10052
# reviews_per_month          0
# host_listings_count        0
# availability_365           0
# dtype: int64

# %%
Airbnb_df1=Airbnb_df.duplicated().sum()

# %%
Airbnb_df.count()
# Out:
# listing_id             48895
# listing_name           48879
# host_id                48895
# host_name              48874
# neighbourhood_group    48895
# neighbourhood          48895
# latitude               48895
# longitude              48895
# room_type              48895
# price                  48895
# minimum_nights         48895
# total_reviews          48895
# last_review            38843
# reviews_per_month      48895
# host_listings_count    48895
# availability_365       48895
# dtype: int64

# %%
Airbnb_df.isnull().sum()
# Out:
# listing_id                 0
# listing_name              16
# host_id                    0
# host_name                 21
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# total_reviews              0
# last_review            10052
# reviews_per_month          0
# host_listings_count        0
# availability_365           0
# dtype: int64

# %%
Airbnb_df['listing_name'].fillna('unknown',inplace=True)
Airbnb_df['host_name'].fillna('no_name',inplace=True)

# %%
Airbnb_df.isnull().sum()
# Out:
# listing_id                 0
# listing_name               0
# host_id                    0
# host_name                  0
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# total_reviews              0
# last_review            10052
# reviews_per_month          0
# host_listings_count        0
# availability_365           0
# dtype: int64

# %%
Airbnb_df[['listing_name','host_name']].isnull().sum()
# Out:
# listing_name    0
# host_name       0
# dtype: int64

# %%
Airbnb_df['listing_name'].isnull().sum()
# Out:
# 0

# %%
Airbnb_df.head(30)
# Out:
#     listing_id                                       listing_name  host_id  \
# 0         2539                 Clean & quiet apt home by the park     2787
# 1         2595                              Skylit Midtown Castle     2845
# 2         3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3         3831                    Cozy Entire Floor of Brownstone     4869
# 4         5022   Entire Apt: Spacious Studio/Loft by central park     7192
# 5         5099          Large Cozy 1 BR Apartment In Midtown East     7322
# 6         5121                                    BlissArtsSpace!     7356
# 7         5178                   Large Furnished Room Near B'way      8967
# 8         5203                 Cozy Clean Guest Room - Family Apt     7490
# 9         5238                 Cute & Cozy Lower East Side 1 bdrm     7549
# 10        5295                   Beautiful 1br on Upper West Side     7702
# ...

# %%
# how to drop the column in dataset

# %%
Airbnb_df = Airbnb_df.drop(['last_review'], axis=1)

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           48895 non-null  int64
#  1   listing_name         48895 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48895 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   latitude             48895 non-null  float64
#  7   longitude            48895 non-null  float64
#  8   room_type            48895 non-null  object
#  9   price                48895 non-null  int64
#  10  minimum_nights       48895 non-null  int64
#  11  total_reviews        48895 non-null  int64
#  12  reviews_per_month    48895 non-null  int64
#  13  host_listings_count  48895 non-null  int64
#  14  availability_365     48895 non-null  int64
# ...

# %%
Airbnb_df.shape
# Out:
# (48895, 15)

# %%
Airbnb_df.isnull().sum()
# Out:
# listing_id             0
# listing_name           0
# host_id                0
# host_name              0
# neighbourhood_group    0
# neighbourhood          0
# latitude               0
# longitude              0
# room_type              0
# price                  0
# minimum_nights         0
# total_reviews          0
# reviews_per_month      0
# host_listings_count    0
# availability_365       0
# dtype: int64

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           48895 non-null  int64
#  1   listing_name         48895 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48895 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   latitude             48895 non-null  float64
#  7   longitude            48895 non-null  float64
#  8   room_type            48895 non-null  object
#  9   price                48895 non-null  int64
#  10  minimum_nights       48895 non-null  int64
#  11  total_reviews        48895 non-null  int64
#  12  reviews_per_month    48895 non-null  int64
#  13  host_listings_count  48895 non-null  int64
#  14  availability_365     48895 non-null  int64
# ...

# %%
Airbnb_df.head(30)
# Out:
#     listing_id                                       listing_name  host_id  \
# 0         2539                 Clean & quiet apt home by the park     2787
# 1         2595                              Skylit Midtown Castle     2845
# 2         3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3         3831                    Cozy Entire Floor of Brownstone     4869
# 4         5022   Entire Apt: Spacious Studio/Loft by central park     7192
# 5         5099          Large Cozy 1 BR Apartment In Midtown East     7322
# 6         5121                                    BlissArtsSpace!     7356
# 7         5178                   Large Furnished Room Near B'way      8967
# 8         5203                 Cozy Clean Guest Room - Family Apt     7490
# 9         5238                 Cute & Cozy Lower East Side 1 bdrm     7549
# 10        5295                   Beautiful 1br on Upper West Side     7702
# ...

# %%
Airbnb_df.sample(5)
# Out:
#        listing_id                                     listing_name   host_id  \
# 27527    21669322  Comfortable & Bright Studio in the East Village   3281798
# 46625    35348968      Light filled private apartment in bed-stuy!  25127792
# 946        363673                 Beautiful 3 bedroom in Manhattan    256239
# 10240     7841904               Modern Private Room in Meatpacking  24976518
# 16805    13411560                  Cozy and charming studio in UWS  26676357
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 27527  Guillermo           Manhattan        East Village  40.73014  -73.98152
# 46625         Té            Brooklyn  Bedford-Stuyvesant  40.69006  -73.95127
# 946       Tracey           Manhattan     Upper West Side  40.80142  -73.96931
# 10240       Mike           Manhattan        West Village  40.74005  -74.00466
# 16805     Connie           Manhattan     Upper West Side  40.77856  -73.98278
#
# ...

# %%
Airbnb_df.sample(5)
# Out:
#        listing_id                                       listing_name  \
# 2502      1281054                         Casa de Chester Baby Kitty
# 16099    13007839                             Second floor apartment
# 31593    24609263  Beautiful 2bdr apt in Brooklyn near to everyth...
# 45270    34646398        Artsy bedroom w/garden & private bathroom .
# 33025    26053340  Beloved Williamsburg, Brooklyn is calling to you!
#
#         host_id host_name neighbourhood_group       neighbourhood  latitude  \
# 2502    6970929      Andy           Manhattan        East Village  40.72160
# 16099  71754921     Berta            Brooklyn       Crown Heights  40.66789
# 31593  43803591      Anna            Brooklyn       Fort Hamilton  40.61257
# 45270   1179779  Sandrine            Brooklyn  Bedford-Stuyvesant  40.69026
# 33025  18824752    Ashley            Brooklyn        Williamsburg  40.70858
#
#        longitude        room_type  price  minimum_nights  total_reviews  \
# ...

# %%
Airbnb_df['listing_id'].nunique()
# Out:
# 48895

# %%
Airbnb_df['neighbourhood'].nunique()
# Out:
# 221

# %%
Airbnb_df['room_type'].nunique()
# Out:
# 3

# %%
Airbnb_df['host_name'].nunique()
# Out:
# 11453

# %%
Airbnb_df[Airbnb_df['host_name']=='Judy']['listing_name'].nunique()
# Out:
# 18

# %%
# this means that the same host David operates different 402 listings/properties

# %%
Airbnb_df[Airbnb_df['host_name']=='Judy']['listing_name'].unique()
# Out:
# array(['Sunny 1 or 2 BR apt in Boerum Hill',
#        'Luxury NYC Studio for Super Bowl 48',
#        'Mid Town East Side Apartment ',
#        'Furnished Room with View of E River',
#        'Huge Private Room in the BEST location',
#        'Comfortable Private Apartment in Heart of Flatbush',
#        'Spacious Bedroom on the East River',
#        'A cozy place to set your mind free.',
#        'Entire Times Square 1BD Apartment',
#        'Quaint & Charming 2BR + Futon',
#        'Private Studio Apartment in Heart of Brooklyn!!',
#        'One bedroom; private house; great location',
#        'Like live in your own home while traveling',
#        'Beautiful 4 Bedroom Apartment', 'Sumpter Suites',
#        'Central Park master room with private bathroom.',
#        'A space like a home',
#        'UWS brownstone with Grdn,  Guest Bdrm, 2 bthrms'], dtype=object)

# %%
Airbnb_df[Airbnb_df['listing_name']==Airbnb_df['host_name']]
# Out:
#        listing_id    listing_name    host_id       host_name  \
# 9473      7264659         Olivier    6994503         Olivier
# 10682     8212051           Monty   43302952           Monty
# 16422    13186374            Sean   35143476            Sean
# 23996    19348168             Cyn   74033595             Cyn
# 24152    19456810  Hillside Hotel  134184451  Hillside Hotel
# 24607    19785737  Hillside Hotel  134184451  Hillside Hotel
# 26734    21231543  Hillside Hotel  134184451  Hillside Hotel
# 26752    21243952  Hillside Hotel  134184451  Hillside Hotel
# 26753    21244035  Hillside Hotel  134184451  Hillside Hotel
# 26889    21311903  Hillside Hotel  134184451  Hillside Hotel
# 26891    21312075  Hillside Hotel  134184451  Hillside Hotel
# 26892    21312191  Hillside Hotel  134184451  Hillside Hotel
# 26893    21312225  Hillside Hotel  134184451  Hillside Hotel
# 26894    21312283  Hillside Hotel  134184451  Hillside Hotel
# ...

# %%
sns.boxplot(x=Airbnb_df['price'])
plt.show()

# %%
Airbnb_df.sample(30)
# Out:
#        listing_id                                       listing_name  \
# 47671    35863336  STUNNING SPACIOUS KING SIZE -BEDROOM NEAR COLU...
# 7621      5729530                 1Br apt on the UES accomodates two
# 28398    22054258              Chambre pour couple où personne seule
# 5943      4349695                    Rustic Chic Private Living Room
# 48538    36311599       Your 1B1B Home in Midtown Clean Cozy & Comfy
# 16082    12999167        Charming & Sunny Studio in the Heart of NYC
# 11803     9184688                 BEAUTIFUL APT ON CENTRAL PARK WEST
# 27564    21692066     South Brooklyn Artist / Student Studio Retreat
# 2245      1063554                bedroom in big sunny loft (& Roof!)
# 16141    13040618                    Sunny and spacious private room
# 28143    21947039  Wyndham Midtown 45 at NYC - 2 Bedroom Presiden...
# 6923      4957358    A Romantic Loft plus terrace  Heart of Brooklyn
# 16960    13492036              Beautiful 1 bedroom in Astoria,Queens
# ...

# %%
def iqr_technique(DFcolumn):
    Q1 = np.percentile(DFcolumn,25)
    Q3 = np.percentile(DFcolumn,75)
    IQR = Q3-Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    
    return lower_range, upper_range

# %%
lower_bound,upper_bound = iqr_technique(Airbnb_df['price'])
lower_bound
# Out:
# -90.0

# %%
upper_bound
# Out:
# 334.0

# %%
lower_bound,upper_bound = iqr_technique(Airbnb_df['price'])
Airbnb_df = Airbnb_df[(Airbnb_df.price>lower_bound) & (Airbnb_df.price<upper_bound)]

# %%
sns.boxplot(x=Airbnb_df['price'])
plt.show()

# %%
Airbnb_df.shape
# Out:
# (45918, 15)

# %%
Airbnb_df['price'].max() #here 333 because we have cosidered the lower value then the upper_bound
# Out:
# 333

# %%
# Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(12,5))

sns.set_theme(style='darkgrid')

sns.distplot(Airbnb_df['price'],color=('r'))

plt.xlabel('price', fontsize=15)
plt.ylabel('Density', fontsize=15)
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(20,5))

sns.set_theme(style='darkgrid')

sns.displot(Airbnb_df['price'],color=('r'))

plt.xlabel('price', fontsize=15)
plt.ylabel('Density', fontsize=15)
# Out:
# Text(-0.30555555555555536, 0.5, 'Density')

# %%
print(Airbnb_df['price'].min())
print(Airbnb_df['price'].max())
# Out:
# 0
# 333

# %% [raw]
# #obsevations
# The range of prices being charged on AIrbnb appears to be from 20 to 330 dollars, with the majority of listings falling in the price range of 50 to 150 dollars.
#
# The distribution of prices appears to have a peak in the 50 to 150 dollars range, with a relatively lower density of listings in the lower and higher price ranges
#
# There may be fewer listings available at price above 250 dollars, as the density of listings drops significanlty in this range

# %% [markdown]
# # Total Listing/property count in Each Neighbourhood Group using Count plot

# %%
Airbnb_df.columns
# Out:
# Index(['listing_id', 'listing_name', 'host_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'total_reviews',
#        'reviews_per_month', 'host_listings_count', 'availability_365'],
#       dtype='object')

# %%
Airbnb_df['listing_name'].value_counts()
# Out:
# listing_name
# Hillside Hotel                                       18
# Home away from home                                  17
# unknown                                              15
# New york Multi-unit building                         13
# Brooklyn Apartment                                   12
#                                                      ..
# Incredible 3 BR Union Square Loft                     1
# NYC living to it's fullest... in a good way!          1
# Spacious Sun Drenched Brick Encrusted Loft            1
# EAST 60TH ST&1ST AVE/ 2BR DOORMAN BLDG                1
# Trendy duplex in the very heart of Hell's Kitchen     1
# Name: count, Length: 44979, dtype: int64

# %%
counts= Airbnb_df['neighbourhood_group'].value_counts()
counts
# Out:
# neighbourhood_group
# Manhattan        19501
# Brooklyn         19415
# Queens            5567
# Bronx             1070
# Staten Island      365
# Name: count, dtype: int64

# %%
#count the number of listings in each neighbourhood group and store the result in pandas series
counts= Airbnb_df['neighbourhood_group'].value_counts()
Top_Neighbourhood_group= counts.reset_index()
Top_Neighbourhood_group.columns=['Neighbourhood_groups','Listing_counts']
Top_Neighbourhood_group
# Out:
#   Neighbourhood_groups  Listing_counts
# 0            Manhattan           19501
# 1             Brooklyn           19415
# 2               Queens            5567
# 3                Bronx            1070
# 4        Staten Island             365

# %%
Airbnb_df.tail(50)
# Out:
#        listing_id                                       listing_name  \
# 48844    36453952    West Village Studio on quiet cobblestone street
# 48845    36454025                                Private 5 star room
# 48846    36454717  #5 New Hotel-Like Private Room  KING bed near JFK
# 48847    36455321  #6 New Hotel-Like Private Room QUEEN Bed near JFK
# 48848    36455402   Cute plant friendly studio in hip Brooklyn area!
# 48849    36455579                          Studio in Manhattan(独立出入)
# 48850    36455584          Large studio at Union Square! for 3-5 ppl
# 48851    36455649   #7 New Hotel-Like Private Room KING bed near JFK
# 48852    36455809            Cozy Private Room in Bushwick, Brooklyn
# 48853    36455917     Sunny&quiet paradise in the WV with open views
# 48854    36456548  Gorgeous Brooklyn Penthouse Apartment w/City V...
# 48855    36456829                  Perfectly Located Organic Getaway
# 48857    36457832      ❥NYC Apt: 4min/subway, 25m/city, 20m/LGA,JFK❥
# ...

# %%
Airbnb_df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    22784
# Private room       21996
# Shared room         1138
# Name: count, dtype: int64

# %%
count=Airbnb_df['room_type'].value_counts()
Top_Neighbourhood=count.reset_index()
Top_Neighbourhood.columns=['room_type','property_counts']
Top_Neighbourhood
# Out:
#          room_type  property_counts
# 0  Entire home/apt            22784
# 1     Private room            21996
# 2      Shared room             1138

# %%
plt.figure(figsize=(13,8))
sns.countplot(data=Airbnb_df,x='neighbourhood_group')
plt.title('Neighbourhood_group Listing Counts in NYC', fontsize=15)
plt.xlabel('Neighbourhood_group', fontsize=14)
plt.ylabel('Total_Listing_counts', fontsize=14)
plt.show()

# %%
Airbnb_df[Airbnb_df['neighbourhood_group']=='Queens']
# Out:
#        listing_id                                       listing_name  \
# 46          12937  1 Stop fr. Manhattan! Private Suite,Landmark B...
# 77          18198                              Little King of Queens
# 143         32363                 Fully Furnished Basement Apartment
# 161         39593            A room w/ a Manhattan view, longer stay
# 196         51850                              ( F) Excellent/Pvt Rm
# ...           ...                                                ...
# 48858    36458668  2beds Private Room Step to LGA, CitiFiled, Mid...
# 48863    36469741                Comfortable & Big room with 2 beds!
# 48866    36472710                                 CozyHideAway Suite
# 48878    36479723                                      Room for rest
# 48889    36484363                                 QUIT PRIVATE HOUSE
#
#          host_id    host_name neighbourhood_group     neighbourhood  latitude  \
# ...

# %%
Airbnb_df[Airbnb_df['neighbourhood_group']=='Staten Island']
# Out:
#        listing_id                                    listing_name    host_id  \
# 169         42882                       New York room with a view     185978
# 249         62452                  A SpeciaL!! Private Room in NY     303939
# 250         62461                     B NYC Staten Alternative...     303939
# 251         62787                     C Private Room By The Ferry     303939
# 256         63320              D Private Che@p Room 2 Explore NYC     303939
# ...           ...                                             ...        ...
# 48401    36237529         Beautiful Cozy Room, 20mn to FREE ferry  272557707
# 48441    36267546                           A Home Away From Home  233485864
# 48446    36270376  Beautiful home on Staten Island, walk to ferry     444904
# 48649    36355110  PRIVATE ROOM IN STATEN ISLAND -FOR LADIES ONLY  201187671
# 48799    36438336                                 Seas The Moment  211644523
#
# ...

# %% [raw]
# observations
#
# Manhattan and Brooklyn have the highest number of listings on Airbnb, with over 19,000 listing each.
#
# Queens and the Bronx have significantly fewer listings compared to manhattan and Brooklyn, with 5,576 and 1070 listings, respectively
#
# Staten island has the fewest number of listings, with only 365
#
# The distribution of listings across the different neighbourhood group is skewed, with a conecntration of listings in Manhatta and Brooklyn.
#
# Despite being larger in size, the neighbourhoods in Queeens , the Bronx, and States island have fewer listings on Airbnb compared to manhattan, which has a smaller geographical area.
#
# This could suggest that the demad for Airbnb rentals is higher in Manhattan compared to the other neighbourhoods, leading to a higher concentration of listings in this area.
#
# Alternatively, it could be that the supply of listings is higher in Manhattan due to a higher number of hometowns or property owners in this neighbourhood who are wiliing to list their properties on Airbnb.

# %% [markdown]
# # Average Price of Each Neighbourhood Group using Point Plot

# %%
from statistics import mean
sns.set_theme(style='whitegrid')
sns.pointplot(x='neighbourhood_group',y='price',data=Airbnb_df, estimator=np.mean)

plt.xlabel('Neighbourhood Group', fontsize=14)
plt.ylabel('Average Price', fontsize=14)
plt.title('Average Price by Neighbourhood group', fontsize=15)
plt.show()

# %%
# Top hosts with more Listing/Property using Bar Chart

# %%
top_10_hosts= Airbnb_df['host_name'].value_counts()[:10].reset_index()
top_10_hosts.columns=['host_name','Total_listings']
top_10_hosts
# Out:
#       host_name  Total_listings
# 0       Michael             383
# 1         David             368
# 2          John             276
# 3  Sonder (NYC)             272
# 4          Alex             253
# 5         Sarah             221
# 6        Daniel             212
# 7         Maria             197
# 8       Jessica             185
# 9          Mike             184

# %%
top_host=Airbnb_df['host_name'].value_counts()[:10]
top_host.plot(kind='bar', color='blue',figsize=(12,8))
plt.xlabel('top10_hosts', fontsize=14)
plt.ylabel('total_NYC_listings', fontsize=14)
plt.title('top 10 hosts on the basis of no of listings in entire NYC!', fontsize=15)
# Out:
# Text(0.5, 1.0, 'top 10 hosts on the basis of no of listings in entire NYC!')

# %% [markdown]
# # Violinplot

# %%
# Creating the violin plot for price distribution in each Neighbourhood_groups

# %%
sns.violinplot(x='neighbourhood_group', y='price',data=Airbnb_df)
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
Airbnb_df.head()
# Out:
#    listing_id                                      listing_name  host_id  \
# 0        2539                Clean & quiet apt home by the park     2787
# 1        2595                             Skylit Midtown Castle     2845
# 2        3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3        3831                   Cozy Entire Floor of Brownstone     4869
# 4        5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  total_reviews  reviews_per_month  \
# ...

# %%
sns.barplot(x='neighbourhood_group',y='price',data=Airbnb_df)
plt.show()

# %%
# Get the top 10 neighborhoods by listing count
count_10=Airbnb_df['neighbourhood'].value_counts().nlargest(10)
top_10_neighbourhood=count_10.reset_index()
top_10_neighbourhood.columns=['neighbourhood','listing_count']
top_10_neighbourhood
# Out:
#         neighbourhood  listing_count
# 0        Williamsburg           3732
# 1  Bedford-Stuyvesant           3638
# 2              Harlem           2585
# 3            Bushwick           2438
# 4     Upper West Side           1788
# 5      Hell's Kitchen           1731
# 6        East Village           1714
# 7     Upper East Side           1670
# 8       Crown Heights           1519
# 9             Midtown           1143

# %%
top_10_neighbourhood=Airbnb_df['neighbourhood'].value_counts().nlargest(10)
colors=['c', 'g', 'olive', 'y', 'm', 'orange', '#C0C0C0', '#800000', '#008000', '#000080']
top_10_neighbourhood.plot(kind='bar',figsize=(13,8), color=colors)
plt.xlabel('Neighbourhood',fontsize=14)
plt.ylabel('Total Listing Counts', fontsize=14)
plt.title('Listings by Top Neighborhoods in NYC', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Listings by Top Neighborhoods in NYC')

# %% [markdown]
# # Number Of Active Hosts Per Location Using Line Chart

# %%
host_per_location=Airbnb_df.groupby('neighbourhood_group')['listing_id'].count().reset_index()
host_per_location.columns=['Neighbourhood_group','Host_counts']
host_per_location
# Out:
#   Neighbourhood_group  Host_counts
# 0               Bronx         1070
# 1            Brooklyn        19415
# 2           Manhattan        19501
# 3              Queens         5567
# 4       Staten Island          365

# %%
Airbnb_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
host_per_location=Airbnb_df.groupby('neighbourhood_group')['listing_id'].count()
locations = host_per_location.index
host_counts=host_per_location.values
plt.figure(figsize=(10,4))
plt.plot(locations, host_counts,marker='o',ms=8,mew=3, mec='r')   #ms-markersize, mew-MarkerEdgeWidth, mec-MarkerEdgeColour
plt.xlabel('Location',fontsize=14)
plt.ylabel('Number of Active Hosts', fontsize=14)
plt.title('Number of Active Hosts per Location', fontsize=15)
plt.show()

# %% [markdown]
# # Total Counts Of Each Room Type

# %%
Total_rooms=Airbnb_df['room_type'].value_counts().reset_index()
Total_rooms.columns=['Room_type','Total_counts']
Total_rooms
# Out:
#          Room_type  Total_counts
# 0  Entire home/apt         22784
# 1     Private room         21996
# 2      Shared room          1138

# %%
#Pie Chart

# %%
plt.figure(figsize=(10,6))
Total_rooms=Airbnb_df['room_type'].value_counts()
labels=Total_rooms.index
sizes=Total_rooms.values
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.legend(title='Room_type', bbox_to_anchor=(0.8,0,0.5,1), fontsize=12)
plt.show()
